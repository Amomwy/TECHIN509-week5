# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_df = pd.read_csv("./data/log.csv")
user_wins = {}

for _, row in data_df.iterrows():
    current_win_username = None
    
    if row["game_result"] == "X":
        current_win_username = row["x_username"]
    elif row["game_result"] == "O":
        current_win_username = row["o_username"]
    
    if current_win_username:
        if current_win_username not in user_wins.keys():
            user_wins[current_win_username] = 1
        else:
            user_wins[current_win_username] += 1

user_wins = dict(sorted(user_wins.items(), key=lambda item: item[1], reverse=True))

usernames = list(user_wins.keys())
wins_time = list(user_wins.values())

# creating the bar plot
fig = plt.figure(figsize = (10, 5))

plt.bar(usernames, wins_time, color ='blue',
        width = 0.4)
 
plt.xlabel("Username in the Game Database")
plt.ylabel("# of Wins")
plt.title("Global Wins Time")
plt.show()

# %%
data_df = pd.read_csv("./data/log.csv")
bot_wins = 0
bot_losses = 0
bot_draws = 0

for _, row in data_df.iterrows():
    if row["o_username"] == "BOT":
        if row["game_result"] == "DRAW":
            bot_draws += 1
        elif row["game_result"] == "O":
            bot_wins += 1
        else:
            bot_losses += 1

# creating the pie chart
labels = 'Wins', 'Losses', 'Draws'
sizes = [bot_wins, bot_losses, bot_draws]
explode = (0.1, 0, 0)

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', startangle=30)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
data_df = pd.read_csv("./data/log.csv")
one_player_times = 0
two_player_times = 0

for _, row in data_df.iterrows():
    if row["o_username"] == "BOT":
        one_player_times += 1
    else:
        two_player_times += 1

        
# creating the pie chart
labels = 'One Player Mode', 'Two Player Mode'
sizes = [one_player_times, two_player_times]
explode = (0.1, 0, 0)

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', startangle=30)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 18
#      15 explode = (0.1, 0, 0)
#      17 fig1, ax1 = plt.subplots()
# ---> 18 ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', startangle=30)
#      19 ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
#      21 plt.show()
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/axes/_axes.py:3172, in Axes.pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize)
#    3170     raise ValueError("'label' must be of length 'x'")
#    3171 if len(x) != len(explode):
# -> 3172     raise ValueError("'explode' must be of length 'x'")
#    3173 if colors is None:
#    3174     get_next_color = self._get_patches_for_fill.get_next_color
#
# ValueError: 'explode' must be of length 'x'
